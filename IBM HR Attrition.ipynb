# %% [markdown]
# # IBM HR Analysis - EDA & Classification
#
# This project is based on a hypothetical dataset downloaded from IBM HR Analytics Employee Attrition & Performance. It has 1,470 data points (rows) and 35 features (columns) describing each employee’s background and characteristics; and labelled (supervised learning) with whether they are still in the company or whether they have gone to work somewhere else. Machine Learning models can help to understand and determine how these factors relate to workforce attrition.

# %% [markdown]
# ## About the data
#
# 1. Attrition: Whether employees are still with the company or whether they’ve gone to work somewhere else.
# 2. Age: 18 to 60 years old
# 3. Gender: Female or Male
# 4. Department: Research & Development, Sales, Human Resources.
# 5. BusinessTravel: Travel_Rarely, Travel_Frequently, Non-Travel.
# 6. DistanceFromHome: Distance between the company and their home in miles.
# 7. MonthlyIncome: Employees' numeric monthly income.
# 8. MaritalStatus: Married, Single, Divorced.
# 9. Education: 1 'Below College' 2 'College' 3 'Bachelor' 4 'Master' 5 'Doctor'.
# 10. EducationField: Life Sciences， Medical， Marketing，Technical Degree，Other.
# 11. EnvironmentSatisfaction: 1 'Low' 2 'Medium' 3 'High' 4 'Very High'.
# 12. RelationshipSatisfaction: 1 'Low' 2 'Medium' 3 'High' 4 'Very High'.
# 13. JobInvolvement: 1 'Low' 2 'Medium' 3 'High' 4 'Very High'.
# 14. JobRole: Sales Executive，Research Science, Laboratory Tec, Manufacturing, Healthcare Rep, etc
# 15. JobSatisfaction: 1 'Low' 2 'Medium' 3 'High' 4 'Very High'.
# 16. OverTime: Whether they work overtime or not.
# 17. NumCompaniesWorked: Number of companies they worked for before joinging IBM.
# 18. PerformanceRating: 1 'Low' 2 'Good' 3 'Excellent' 4 'Outstanding'.
# 19. YearsAtCompany: Years they worked for IBM.
# 20. WorkLifeBalance: 1 'Bad' 2 'Good' 3 'Better' 4 'Best'.
# 21. YearsSinceLastPromotion: Years passed since their last promotion.

# %%
# Importing the data

import pandas as pd
import numpy as np

df = pd.read_csv(r'C:\Users\User\Desktop\Projects\WA_Fn-UseC_-HR-Employee-Attrition.csv')
pd.options.display.max_columns = None
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 1465            2061                        3   Male          41
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
# Deleting duplicate rows
df[df.duplicated(keep='first')].shape
# Out:
# (0, 35)

# %% [markdown]
# It is clear that there were no duplicate entries in the data

# %% [markdown]
# #### Eliminating columns that only have one data level
#
# Such columns do not contribute towards model building in any way

# %%
temp = []
for col in df.columns:
    if len(df[col].unique()) == 1:
        temp.append(col)
        df.drop(col,inplace=True,axis=1)

df.shape
# Out:
# (1470, 32)

# %%
temp
# Out:
# ['EmployeeCount', 'Over18', 'StandardHours']

# %% [markdown]
# 'EmployeeCount', 'Over18' and 'StandardHours' columns are deleted

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# ...

# %% [markdown]
# 1. There are total of 1470 rows.
# 2. We can infer that there are no missing values.
# 3. Average age of employees at IBM is 36 and average Monthly Income is 14,313 unit.
# 4. The column ‘MonthlyIncome’, ‘TotalWorkingYears’,‘YearsAtCompany’,‘YearsInCurrentRole’,‘YearsSinceLastPromotion’,‘YearsWithCurrManager’ is suspectable of consisting outliers, as it observes a large difference between it 3rd Quartile Value and Maximum value.
# 5. It is also noticed that employee number seems to have unique value for each entry and thus is of no importance to the model, thus it should be dropped

# %%
df['EmployeeNumber'].unique()
# Out:
# array([   1,    2,    4, ..., 2064, 2065, 2068], dtype=int64)

# %%
# Drpping EmployeeNumber column as stated above
df.drop(['EmployeeNumber'], axis = 1, inplace = True)

# %%
df.describe(include=['O'])
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus OverTime
# count              1470          1470     1470
# unique                9             3        2
# top     Sales Executive       Married       No
# freq                326           673     1054

# %% [markdown]
# #### Checking for null values

# %%
df.isnull().any()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StockOptionLevel            False
# TotalWorkingYears           False
# TrainingTimesLastYear       False
# WorkLifeBalance             False
# ...

# %% [markdown]
# The data does not have any null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
df.shape
# Out:
# (1470, 31)

# %% [markdown]
# ### Summary
#
# Dataset info:
#
# - Number of variables: 31
# - Number of observations: 1470
# - Missing cells: 0
#
# Variables types:
#
# - Numeric: 23
# - Categorical: 8
#
# Observations:
#
# - Target variable is of categorical type, hence this is a Classification Type Problem

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns

# %% [markdown]
# ### Vizualizing Categorical Variables

# %% [markdown]
# #### Atriation

# %%
sns.countplot(x='Attrition', data=df, palette='winter')

# %% [markdown]
# This figure is showing the distribution of employee attrition. In this dataset, majority employees stayed in the company.
# #### The data is very imbalanced, which could potentially lead to problems in training the model.

# %% [markdown]
# #### Marital Status

# %%
sns.countplot(x='MaritalStatus', data=df, palette='winter')

# %% [markdown]
# Among the IBM wmployees:
# - majority are married
# - a fair share is single
# - and the least amount of crowd is divorced

# %%
plt.figure(figsize=(8,4))
sns.barplot(x = 'MaritalStatus',y = 'PerformanceRating',data = df, palette='winter')

# %% [markdown]
# The Marital Status of the employee does not have a say in their performance

# %%
plt.subplots(figsize=(8,4))
sns.countplot(x='MaritalStatus', hue='Gender', data=df, palette='winter')
plt.title('Marital Status')
# Out:
# Text(0.5, 1.0, 'Marital Status')

# %% [markdown]
# Among the IBM employees
# - Men dominate the marital status category in number in any category.
# - The least difference the count of Male and Female is in the Single category.

# %% [markdown]
# #### Business Travel

# %%
sns.countplot(x='BusinessTravel', data=df, palette='winter')

# %%
plt.subplots(figsize=(8,4))
sns.countplot(x='BusinessTravel', hue='Attrition',data=df, palette='winter')

# %% [markdown]
# - Employees who do not travel for business are least likely to Leave the company

# %%
plt.figure(figsize=(8,4))
sns.barplot(x = 'BusinessTravel',y = 'PerformanceRating',data = df, palette='winter')

# %% [markdown]
# Bussiness Travels have no effect on Performance

# %%
plt.subplots(figsize=(8,4))
sns.countplot(x='BusinessTravel',hue='Gender', data=df, palette='winter')

# %% [markdown]
# - There is not much difference between the number of Males and Females who Travel frequently for difference

# %% [markdown]
# #### Gender

# %%
sns.countplot(x='Gender', data=df, palette='winter')

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'Gender',y = 'MonthlyIncome',data = df, palette='winter')

# %% [markdown]
# - IBM Female Employees have a higher monthly income compared to males

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'Gender',y = 'JobSatisfaction',data = df, palette='winter')

# %% [markdown]
# - Females are less satisfied by their job as compared to males

# %%
sns.catplot(x="Attrition",kind="count",col="Gender",data=df, palette='winter')

# %% [markdown]
# - Males are more likely to leave than females

# %% [markdown]
# #### Job Role

# %%
plt.figure(figsize=(21,5))
sns.countplot(x='JobRole', data=df, palette='winter')

# %%
plt.figure(figsize=(10,5))
g = sns.barplot(x = 'JobSatisfaction', y = 'JobRole',data = df, palette='winter')

# %% [markdown]
# On Average Healthcare Representatives are the most and HR Employees are the least satisfied employees

# %%
plt.figure(figsize=(10,5))
sns.barplot(y = 'JobRole', x = 'Education',data = df,estimator=np.median, palette='winter')

# %% [markdown]
# Apart from Sales, Job Roles at IBM demands high educational requirement

# %%
plt.figure(figsize=(6,3))
sns.catplot(x="JobLevel",kind="count",col="Attrition",data=df, palette='winter')

# %% [markdown]
# - Employees on higher job levels are less likely to leave the company

# %%
plt.subplots(figsize=(10,6))
fig = plt.gcf()
fig.set_size_inches(20,14)
sns.countplot(x='JobRole', hue='Gender',data=df, palette='winter')
plt.title('Job Role Between Male and Female')
# Out:
# Text(0.5, 1.0, 'Job Role Between Male and Female')

# %% [markdown]
# - Every job role is dominated by males
# - Manufacturing Director job role has almost same number of males and females

# %% [markdown]
# #### Education Field

# %%
plt.figure(figsize=(10,4))
sns.countplot(x='EducationField', data=df, palette='winter')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'EducationField', y = 'Education',data = df,estimator=np.median, palette='winter')

# %% [markdown]
# At IBM people from different educatoional backgrounds are equally and highly educated.

# %%
plt.subplots(figsize=(12,5))
sns.countplot(x='EducationField', hue='Gender',data=df, palette='winter')

# %% [markdown]
# - Every Education Field is dominated by males

# %% [markdown]
# #### Department

# %%
sns.countplot(x='Department', data=df, palette='winter')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'Department', y = 'Education',data = df,estimator=np.median, palette='winter')

# %% [markdown]
# All departments are equally educated

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x = 'Department', y = 'JobInvolvement',data = df, palette='winter')

# %% [markdown]
# All the Departments are equally involved at work

# %%
plt.subplots(figsize=(8, 4))
sns.countplot(x='Department', hue='Gender',data=df, palette='winter')

# %%
plt.subplots(figsize=(8,4))
sns.countplot(x='Department', hue='Attrition',data=df, palette='winter')

# %% [markdown]
# - Research Developement Department employees are more likely to resign

# %% [markdown]
# ## Vizualizing Numerical Varaibles

# %% [markdown]
# #### Age

# %%
plt.subplots(figsize=(10,4))
sns.distplot(df['Age'],color='orange')
plt.title('Age of the Employees distribution \n Median:{0:.2f} Years'.format(df['Age'].median()),size=25)
plt.axvline(df['Age'].median(),color='black',label='Median')
plt.legend()

# %% [markdown]
# - Average age of an IBM empoyee is 36 Years
# - Majority employees at IBM fall under the age category 25-45

# %% [markdown]
# #### Distance From Home

# %%
plt.subplots(figsize=(10,4))
sns.distplot(df['DistanceFromHome'],color='orange')
plt.title('Distance of Office From Home of the Employees distribution \n Median:{0:.2f}'.format(df['DistanceFromHome'].median()),size=25)
plt.axvline(df['DistanceFromHome'].median(),color='black',label='Median')
plt.legend()

# %% [markdown]
# - Average distance of home from the office for the employees of IBM is 7 units

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x = 'Attrition',y = 'DistanceFromHome',data = df, palette='winter')

# %% [markdown]
# Employees who attrited had their homes farther than rest of the employees

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x = 'PerformanceRating', y = 'DistanceFromHome',data = df, palette='winter')

# %% [markdown]
# Distance of an employee's home from office has no effect in his/her performance

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x = 'JobSatisfaction', y = 'DistanceFromHome',data = df, palette='winter')

# %% [markdown]
# Similarly Distance from home does not affcet Job Satisfaction

# %% [markdown]
# #### Environment Satisfaction

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'Attrition',y = 'EnvironmentSatisfaction',data = df, palette='winter')

# %% [markdown]
# #### Monthly Income

# %%
plt.subplots(figsize=(10,4))
sns.distplot(df['MonthlyIncome'],color='orange')
plt.title('Distance of Monthly Income of the Employees distribution \n Median:{0:.2f}'.format(df['MonthlyIncome'].median()),size=25)
plt.axvline(df['MonthlyIncome'].median(),color='black',label='Median')
plt.legend()

# %% [markdown]
# Average monthly income of an IBM empoyee is around 5000

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x = 'Attrition',y = 'MonthlyIncome',data = df, palette='winter')

# %% [markdown]
# It's obvious that the attrited employees had lower Monthly Income than others but there are many outliers

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'Education',y = 'MonthlyIncome',data = df, palette='winter')

# %% [markdown]
# Higher levels of education tends to Higher Income

# %% [markdown]
# #### Years At Company

# %%
plt.subplots(figsize=(10,4))
sns.distplot(df['YearsAtCompany'],color='orange')
plt.title('Distance of Years At Company of the Employees distribution \n Median:{0:.2f} years'.format(df['YearsAtCompany'].median()),size=25)
plt.axvline(df['YearsAtCompany'].median(),color='black',label='Median')
plt.legend()

# %% [markdown]
# Average Years for which an empoyee has worked at IBM is between 5 Years

# %%
plt.figure(figsize=(8,4))
sns.boxplot(y = 'Attrition',x = 'YearsAtCompany',data = df, palette='winter')

# %% [markdown]
# The attrited employees were working for lesser years than others but there are exceptions

# %%
plt.figure(figsize=(20,6))
sns.barplot(x = 'YearsAtCompany', y = 'JobSatisfaction',data = df, palette='winter')

# %% [markdown]
# There isn't any trend in Working Years and Job Satisfaction

# %% [markdown]
# #### Education

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'Education',y = 'PerformanceRating',data = df, palette='winter')

# %% [markdown]
# The level of education acquired by the employee does not affect their performance negatively or possitively

# %%
sns.countplot(x="Education",hue="Attrition",data=df, palette='winter')
plt.xticks([0,1,2,3,4],["Below College","College","Bachelor","Master","Doctor"])
plt.title("Education Level on Attrition")
plt.show()

# %% [markdown]
# - The higher the degree of the employee, the less likely they are to leave
# - Bachelor Degree Holders are most likely to leave

# %% [markdown]
# #### Salary Hike

# %%
sns.boxplot(y = 'OverTime', x = 'PercentSalaryHike',data = df, palette='winter')

# %% [markdown]
# Overtime isn't likely to get the employee an increase in salary

# %%
sns.boxplot(df['Attrition'],df['PercentSalaryHike'], palette='winter')

# %% [markdown]
# This column have similar distribution so, can be eliminated

# %% [markdown]
# #### Job Satisfaction

# %%
sns.countplot(x="JobSatisfaction",hue="Attrition",data=df, palette='winter')
plt.xticks([0,1,2,3],['Low','Medium','High','Very High'])
plt.title("Job Satisfaction on Attrition")
plt.show()

# %% [markdown]
# - Attrition can be expeced to take place irrespective of the job satisfaction
# - A higher job satisfaction does not guarantee that the employee will stay

# %% [markdown]
# #### Job Involvement

# %%
sns.countplot(x="JobInvolvement",hue="Attrition",data=df, palette='winter')
plt.xticks([0,1,2,3],['Low','Medium','High','Very High'])
plt.title("Job Involvement on Attrition")
plt.show()

# %% [markdown]
# - Employees with high job involvement are most likely to churn than the rest

# %% [markdown]
# #### Daily Rate

# %%
sns.set_style('whitegrid')
g = sns.FacetGrid(df, col='Attrition')
g.map(plt.hist, 'DailyRate', bins=15)

# %% [markdown]
# #### Monthly Rate

# %%
sns.set_style('whitegrid')
g = sns.FacetGrid(df, col='Attrition')
g.map(plt.hist, 'MonthlyRate', bins=15)

# %% [markdown]
# #### Hourly Rate

# %%
sns.set_style('whitegrid')
g = sns.FacetGrid(df, col='Attrition')
g.map(plt.hist, 'HourlyRate', bins=15)

# %% [markdown]
# # Correlation

# %%
f, ax = plt.subplots(figsize=(20, 20))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax, annot = True)

# %% [markdown]
# - From the correlation table we see that daily rate, hourly rate and monthly rate are barely correlated with anything.
# and since monthly income is more suitable for analysis as a measurement of salary It is better to get rid of other income related variables.

# %%
df.drop(['DailyRate', 'HourlyRate', 'MonthlyRate'], axis = 1, inplace = True)

# %% [markdown]
# Some other conclusions we get from the correlation table:
#
# 1. Job level and total working years are highly correlated.
# 2. Monthly Income and total working years are highly correlated(0.95)
# 3. Performance rating and percentage salary hike are highly correlated(0.77)
# 4. It is preffered to drop both the above columns
# 5. Years in current role and years at company are highly correlated.
# 6. Years with current manager and years at company are highly correlated.

# %%
df.drop(['JobLevel', 'TotalWorkingYears'], axis = 1, inplace = True)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# #### Checking for Outliers

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 6))

sns.boxplot(ax=axes[0, 0], x=df['MonthlyIncome'])
sns.boxplot(ax=axes[0, 1], x=df['Age'])
sns.boxplot(ax=axes[0, 2], x=df['YearsAtCompany'])
sns.boxplot(ax=axes[1, 0], x=df['YearsInCurrentRole'])
sns.boxplot(ax=axes[1, 1], x=df['YearsSinceLastPromotion'])
sns.boxplot(ax=axes[1, 2], x=df['YearsWithCurrManager'])

# %% [markdown]
#  All the variables contain outliers except Age

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Treating these Outliers

# %%
#for value in colname:
q1 = df['MonthlyIncome'].quantile(0.25) #first quartile value
q3 = df['MonthlyIncome'].quantile(0.75) # third quartile value
iqr = q3-q1 #Interquartile range
low  = q1-1.5*iqr #acceptable range
high = q3+1.5*iqr #acceptable range

df_include = df.loc[(df['MonthlyIncome'] >= low) & \
                                (df['MonthlyIncome'] <= high)] # meeting the acceptable range
df_exclude = df.loc[(df['MonthlyIncome'] < low) | \
                               (df['MonthlyIncome'] > high)] #not meeting the acceptable range

print(df_include.shape, df_exclude.shape)

age_mean=int(df_include.MonthlyIncome.mean()) #finding the mean of the acceptable range
print(age_mean)

#imputing outlier values with mean value
df_exclude.MonthlyIncome=age_mean

#getting back the original shape of df
df = pd.concat([df_include,df_exclude]) #concatenating both dfs to get the original shape
print(df.shape)

#capping approach
df_exclude.loc[df_exclude["MonthlyIncome"] <low, "age"] = low
df_exclude.loc[df_exclude["MonthlyIncome"] >high, "age"] = high
# Out:
# (1356, 26) (114, 26)
# 5502
# (1470, 26)

# %%
#for value in colname:
q1 = df['YearsAtCompany'].quantile(0.25) #first quartile value
q3 = df['YearsAtCompany'].quantile(0.75) # third quartile value
iqr = q3-q1 #Interquartile range
low  = q1-1.5*iqr #acceptable range
high = q3+1.5*iqr #acceptable range

df_include = df.loc[(df['YearsAtCompany'] >= low) & \
                                (df['YearsAtCompany'] <= high)] # meeting the acceptable range
df_exclude = df.loc[(df['YearsAtCompany'] < low) | \
                               (df['YearsAtCompany'] > high)] #not meeting the acceptable range

print(df_include.shape, df_exclude.shape)

age_mean=int(df_include.YearsAtCompany.mean()) #finding the mean of the acceptable range
print(age_mean)

#imputing outlier values with mean value
df_exclude.YearsAtCompany=age_mean

#getting back the original shape of df
df = pd.concat([df_include,df_exclude]) #concatenating both dfs to get the original shape
print(df.shape)

#capping approach
df_exclude.loc[df_exclude["YearsAtCompany"] <low, "age"] = low
df_exclude.loc[df_exclude["YearsAtCompany"] >high, "age"] = high
# Out:
# (1366, 26) (104, 26)
# 5
# (1470, 26)

# %%
#for value in colname:
q1 = df['YearsInCurrentRole'].quantile(0.25) #first quartile value
q3 = df['YearsInCurrentRole'].quantile(0.75) # third quartile value
iqr = q3-q1 #Interquartile range
low  = q1-1.5*iqr #acceptable range
high = q3+1.5*iqr #acceptable range

df_include = df.loc[(df['YearsInCurrentRole'] >= low) & \
                                (df['YearsInCurrentRole'] <= high)] # meeting the acceptable range
df_exclude = df.loc[(df['YearsInCurrentRole'] < low) | \
                               (df['YearsInCurrentRole'] > high)] #not meeting the acceptable range

print(df_include.shape, df_exclude.shape)

age_mean=int(df_include.YearsInCurrentRole.mean()) #finding the mean of the acceptable range
print(age_mean)

#imputing outlier values with mean value
df_exclude.YearsInCurrentRole=age_mean

#getting back the original shape of df
df = pd.concat([df_include,df_exclude]) #concatenating both dfs to get the original shape
print(df.shape)

#capping approach
df_exclude.loc[df_exclude["YearsInCurrentRole"] <low, "age"] = low
df_exclude.loc[df_exclude["YearsInCurrentRole"] >high, "age"] = high
# Out:
# (1449, 26) (21, 26)
# 4
# (1470, 26)

# %%
#for value in colname:
q1 = df['YearsInCurrentRole'].quantile(0.25) #first quartile value
q3 = df['YearsInCurrentRole'].quantile(0.75) # third quartile value
iqr = q3-q1 #Interquartile range
low  = q1-1.5*iqr #acceptable range
high = q3+1.5*iqr #acceptable range

df_include = df.loc[(df['YearsSinceLastPromotion'] >= low) & \
                                (df['YearsSinceLastPromotion'] <= high)] # meeting the acceptable range
df_exclude = df.loc[(df['YearsSinceLastPromotion'] < low) | \
                               (df['YearsSinceLastPromotion'] > high)] #not meeting the acceptable range

print(df_include.shape, df_exclude.shape)

age_mean=int(df_include.YearsSinceLastPromotion.mean()) #finding the mean of the acceptable range
print(age_mean)

#imputing outlier values with mean value
df_exclude.YearsSinceLastPromotion=age_mean

#getting back the original shape of df
df = pd.concat([df_include,df_exclude]) #concatenating both dfs to get the original shape
print(df.shape)

#capping approach
df_exclude.loc[df_exclude["YearsSinceLastPromotion"] <low, "age"] = low
df_exclude.loc[df_exclude["YearsSinceLastPromotion"] >high, "age"] = high
# Out:
# (1457, 26) (13, 26)
# 2
# (1470, 26)

# %%
#for value in colname:
q1 = df['YearsInCurrentRole'].quantile(0.25) #first quartile value
q3 = df['YearsInCurrentRole'].quantile(0.75) # third quartile value
iqr = q3-q1 #Interquartile range
low  = q1-1.5*iqr #acceptable range
high = q3+1.5*iqr #acceptable range

df_include = df.loc[(df['YearsInCurrentRole'] >= low) & \
                                (df['YearsInCurrentRole'] <= high)] # meeting the acceptable range
df_exclude = df.loc[(df['YearsInCurrentRole'] < low) | \
                               (df['YearsInCurrentRole'] > high)] #not meeting the acceptable range

print(df_include.shape, df_exclude.shape)

age_mean=int(df_include.YearsInCurrentRole.mean()) #finding the mean of the acceptable range
print(age_mean)

#imputing outlier values with mean value
df_exclude.YearsInCurrentRole=age_mean

#getting back the original shape of df
df = pd.concat([df_include,df_exclude]) #concatenating both dfs to get the original shape
print(df.shape)

#capping approach
df_exclude.loc[df_exclude["YearsInCurrentRole"] <low, "age"] = low
df_exclude.loc[df_exclude["YearsInCurrentRole"] >high, "age"] = high
# Out:
# (1470, 26) (0, 26)
# 4
# (1470, 26)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-73b4038977cd> in <module>
#      24
#      25 #capping approach
# ---> 26 df_exclude.loc[df_exclude["YearsInCurrentRole"] <low, "age"] = low
#      27 df_exclude.loc[df_exclude["YearsInCurrentRole"] >high, "age"] = high
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668             key = com.apply_if_callable(key, self.obj)
#     669         indexer = self._get_setitem_indexer(key)
# --> 670         self._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     835                             if not is_list_like_indexer(value):
# ...

# %% [markdown]
# #### Encoding the categorical data

# %%
# Transform categorical data into dummies
dummy_col = [column for column in df.drop('Attrition', axis=1).columns if df[column].nunique() < 20]
data = pd.get_dummies(df, columns=dummy_col, drop_first=True, dtype='uint8')

# %%
data.shape, df.shape
# Out:
# ((1470, 140), (1470, 26))

# %%
# LabelEncoding target variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Attrition']=le.fit_transform(data['Attrition'])

# %%
data.shape
# Out:
# (1470, 140)

# %% [markdown]
# #### Shuffling the data before splitting

# %%
data = data.sample(frac = 1, random_state=0)

# %% [markdown]
# #### Splitting the data

# %%
x = data.drop(columns=['Attrition'])
y = data[['Attrition']]

# %%
x.shape, y.shape
# Out:
# ((1470, 139), (1470, 1))

# %% [markdown]
# #### Performing PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=30)
x = pca.fit_transform(x)
x = pd.DataFrame(data=x)
x.shape
# Out:
# (1470, 30)

# %% [markdown]
# #### Scaling the data

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %% [markdown]
# # Training Phase

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=.22,random_state=47)

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lg = LogisticRegression()
lg.fit(train_x, train_y)
pred = lg.predict(test_x)
log = accuracy_score(test_y,pred)*100

print('accuracy score:', log)
print('\n')
print (classification_report(test_y,pred))
# Out:
# accuracy score: 86.41975308641975
#
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92       271
#            1       0.70      0.30      0.42        53
#
#     accuracy                           0.86       324
#    macro avg       0.79      0.64      0.67       324
# weighted avg       0.85      0.86      0.84       324

# %% [markdown]
# ## GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(train_x,train_y)
predgnb= gnb.predict(test_x)
gaussian = accuracy_score(test_y,predgnb)*100

print('accuracy score:',gaussian)
print('\n')
print(confusion_matrix(test_y, predgnb))
print('\n')
print(classification_report(test_y, predgnb))
# Out:
# accuracy score: 86.11111111111111
#
#
# [[265   6]
#  [ 39  14]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       271
#            1       0.70      0.26      0.38        53
#
#     accuracy                           0.86       324
#    macro avg       0.79      0.62      0.65       324
# weighted avg       0.84      0.86      0.83       324

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
svc=SVC(kernel='linear',probability=True)
svc.fit(train_x,train_y)
svc.score(train_x,train_y)
predsvc=svc.predict(test_x)
svcs = accuracy_score(test_y, predsvc)*100

print('accuracy score:',svcs)
print('\n')
print(confusion_matrix(test_y, predsvc))
print('\n')
print(classification_report(test_y, predsvc))
# Out:
# accuracy score: 83.64197530864197
#
#
# [[271   0]
#  [ 53   0]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       271
#            1       0.00      0.00      0.00        53
#
#     accuracy                           0.84       324
#    macro avg       0.42      0.50      0.46       324
# weighted avg       0.70      0.84      0.76       324

# %% [markdown]
# ## DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier
dtc =DecisionTreeClassifier(criterion='entropy')
dtc.fit(train_x,train_y)
dtc.score(train_x,train_y)
preddtc=dtc.predict(test_x)
decision_e = accuracy_score(test_y, preddtc)*100

print('accuracy score:',decision_e )
print('\n')
print(confusion_matrix(test_y, preddtc))
print('\n')
print(classification_report(test_y, preddtc))
# Out:
# accuracy score: 79.62962962962963
#
#
# [[241  30]
#  [ 36  17]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       271
#            1       0.36      0.32      0.34        53
#
#     accuracy                           0.80       324
#    macro avg       0.62      0.61      0.61       324
# weighted avg       0.79      0.80      0.79       324

# %% [markdown]
# ## RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100,random_state=75) 
rf.fit(train_x,train_y)
predrf = rf.predict(test_x)
random = accuracy_score(test_y,predrf)*100

print('accuracy score:',random)
print('\n')
print(confusion_matrix(test_y,predrf))
print(classification_report(test_y,predrf))
# Out:
# accuracy score: 83.9506172839506
#
#
# [[269   2]
#  [ 50   3]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91       271
#            1       0.60      0.06      0.10        53
#
#     accuracy                           0.84       324
#    macro avg       0.72      0.52      0.51       324
# weighted avg       0.80      0.84      0.78       324

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors =5)
knn.fit(train_x,train_y)
knn.score(train_x,train_y)
predknn = knn.predict(test_x)
knn_a = accuracy_score(test_y, predknn)*100

print('accuracy score:',knn_a)
print('\n')
print(confusion_matrix(test_y, predknn))
print('\n')
print(classification_report(test_y, predknn))
# Out:
# accuracy score: 84.25925925925925
#
#
# [[264   7]
#  [ 44   9]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91       271
#            1       0.56      0.17      0.26        53
#
#     accuracy                           0.84       324
#    macro avg       0.71      0.57      0.59       324
# weighted avg       0.81      0.84      0.81       324

# %% [markdown]
# ## GradientBoost

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbr = GradientBoostingClassifier(random_state=0)
gbr.fit(train_x,train_y)
gbr.score(train_x,train_y)
predgbr = gbr.predict(test_x)
gbr_a = accuracy_score(test_y, predgbr)*100

print('accuracy score:',gbr_a)
print('\n')
print(confusion_matrix(test_y, predgbr))
print('\n')
print(classification_report(test_y, predgbr))
# Out:
# accuracy score: 84.87654320987654
#
#
# [[266   5]
#  [ 44   9]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92       271
#            1       0.64      0.17      0.27        53
#
#     accuracy                           0.85       324
#    macro avg       0.75      0.58      0.59       324
# weighted avg       0.82      0.85      0.81       324

# %% [markdown]
# ## ExtraaClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
reg = ExtraTreesClassifier()
reg.fit(train_x, train_y)
reg.score(train_x,train_y)
predreg = reg.predict(test_x)
reg_a = accuracy_score(test_y, predreg)*100

print('accuracy score:',reg_a)
print('\n')
print(confusion_matrix(test_y, predreg))
print('\n')
print(classification_report(test_y, predreg))
# Out:
# accuracy score: 83.9506172839506
#
#
# [[271   0]
#  [ 52   1]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       271
#            1       1.00      0.02      0.04        53
#
#     accuracy                           0.84       324
#    macro avg       0.92      0.51      0.47       324
# weighted avg       0.87      0.84      0.77       324

# %% [markdown]
# ## XGB

# %%
from xgboost import XGBClassifier

xbg = XGBClassifier()
xbg.fit(train_x, train_y)
xbg.score(train_x,train_y)
predxbg = xbg.predict(test_x)
xbg_a = accuracy_score(test_y, predxbg)*100

print('accuracy score:',xbg_a)
print('\n')
print(confusion_matrix(test_y, predxbg))
print('\n')
print(classification_report(test_y, predxbg))
# Out:
# [10:14:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# accuracy score: 85.18518518518519
#
#
# [[268   3]
#  [ 45   8]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       271
#            1       0.73      0.15      0.25        53
#
#     accuracy                           0.85       324
#    macro avg       0.79      0.57      0.58       324
# weighted avg       0.84      0.85      0.81       324

# %% [markdown]
# ## Picking the best model

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression', 'Gaussian Naive Bayes', 'Decision Tree',
              'Random Forest','Support Vector Machines', 'KNN', 'GradientBoost', 'ExtraaTree', 'XGBoost' ],
    'Score': [log,gaussian,svcs,decision_e,random,knn_a,gbr_a,reg_a,xbg_a]})
models.sort_values(by='Score', ascending=False)
# Out:
#                      Model      Score
# 0      Logistic Regression  86.419753
# 1     Gaussian Naive Bayes  86.111111
# 8                  XGBoost  85.185185
# 6            GradientBoost  84.876543
# 5                      KNN  84.259259
# 4  Support Vector Machines  83.950617
# 7               ExtraaTree  83.950617
# 2            Decision Tree  83.641975
# 3            Random Forest  79.629630

# %% [markdown]
# Logistic Regression is giving the best score however, since data is highly imbalanced there is a major scope of improvement

# %% [markdown]
# ## Performing RandomOverSampling on top 3 Models
# Oversampling increases the weight of the minority class by replicating the minority class examples.
# - ADASYN generates samples of the minority class according to their density distributions.

# %% [markdown]
# We Pick the top 3 best performing models and perform Oversampling on them
# 1. Logistic Regression
# 2. Gaussian Naive Bayes
# 3. XGBoost

# %%
from imblearn.over_sampling import (ADASYN)

sampler = ADASYN(random_state=0)
X_resampled, y_resampled = sampler.fit_resample(x, y)
X_resampled.shape,y_resampled.shape
# Out:
# ((2393, 30), (2393, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, 
                                                    test_size=0.25, 
                                                    random_state=42,stratify=y_resampled)

# %%
lg = LogisticRegression()
lg.fit(X_train, y_train)
pred = lg.predict(X_test)
print('Accuracy Score', accuracy_score(y_test,pred))
from sklearn.model_selection import cross_val_score
print('Cross Val Score', cross_val_score(lg,X_resampled,y_resampled).mean())
# Out:
# Accuracy Score 0.7262103505843072
# Cross Val Score 0.7183462758012247

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
pred = gnb.predict(X_test)
print('Accuracy Score', accuracy_score(y_test,pred))
from sklearn.model_selection import cross_val_score
print('Cross Val Score', cross_val_score(gnb,X_resampled,y_resampled).mean())
# Out:
# Accuracy Score 0.7712854757929883
# Cross Val Score 0.7647487355980468

# %%
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
pred = xgb.predict(X_test)
print('Accuracy Score', accuracy_score(y_test,pred))
from sklearn.model_selection import cross_val_score
print('Cross Val Score', cross_val_score(xbg,X_resampled,y_resampled).mean())
# Out:
# [10:14:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy Score 0.9432387312186978
# [10:14:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:14:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %% [markdown]
# XGBoost is giving the best result, that is 94% after oversampling and since the CrossValScore is not much different from the accuracy score thus Oversampling is not causing any hinderence to the model.
#
# Thus XGBOOST is our final model

# %% [markdown]
# #### Confusion Matrix - XGBoost
# Checking the confusion matrix representation of our finalized model

# %%
def conf_matrix(y_test,pred):
    cm = confusion_matrix(y_test,pred)
    plt.figure(figsize=(7,7))
    sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'YlGnBu');
    plt.ylabel('Actual label');
    plt.xlabel('Predicted label');
    all_sample_title = 'Confusion Matrix - score:'+str(accuracy_score(y_test,pred))
    plt.title(all_sample_title, size = 15);
    plt.show()
    print(classification_report(y_test,pred))
conf_matrix(y_test,pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94       309
#            1       0.92      0.96      0.94       290
#
#     accuracy                           0.94       599
#    macro avg       0.94      0.94      0.94       599
# weighted avg       0.94      0.94      0.94       599

# %% [markdown]
# #### ROC Curve - XGBoost

# %%
def plot_roc_curve(y_test,X_test,model):
    fpr_mlp, tpr_mlp, thresholds_mlp = roc_curve(y_test, model.predict_proba(X_test)[:,1])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr_mlp, tpr_mlp)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC CURVE')
    plt.show()
plot_roc_curve(y_test,X_test,xgb)

# %% [markdown]
# #### Saving the best model

# %%
import pickle

filename = 'HR_classi.pkl'
pickle.dump(xgb, open(filename, 'wb'))

# %% [markdown]
# ## Observations
#
# 1. Employees tend to switch to a different jobs at the start of their careers.
#
#
# 2. Once the employees have found stability in their jobs and personal life (have been married), they tend to stay longer in the organization.
#
#
# 3. Salary and stock ptions are a great motivating factor for the employees and they tend to leave the organization much lesser.
#
#
# 4. Higher pay and more stock options have the employees remain loyal to the company.
#
#
# 5. Work life balance is a great motivation factor for the employees. However, employees with a good work-life balance, tend to switch in search of better opportunities and a better standard of living.
#
#
# 6. Departments where target meeting performance is very much crucial (for e.g. Sales) tend to have a greater chances of leaving the organization as compared to departments with more administration perspective (For e.g. Human Resources)
#
#
# 7. People with a good Job Satisfaction and Environment satisfaction are loyal to the organization
#
#
# 8. Employees who are not much satisfied with their current Job tend to leave the organization far more.
#
#
# ## Managerial Insights
#
# 1. The company should look deeper into human resource roles to understanding which part people are not satisfied with the job.
#
#
# 2. The company doesn’t need to worry too much about people who worked for 2 – 4 companies, it does need to pay close attention to their male employees who have already attired from more than 5 companies.
#
#
# 3. Doctors are not very satisfied with their jobs at level 3 and are having a longer time to be promoted from job level 3 to job level 4. It is recommended to make sure that people are rewarded properly.
